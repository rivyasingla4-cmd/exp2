# %%
 # rivya
 # Aim:study of list,tuple and dictionary
 listfruits=["apple","orange","cherry",]
 print(listfruits)
# Out:
# ['apple', 'orange', 'cherry']

# %%
listfruits=["apple","orange","cherry","apple"]
print(listfruits)
# Out:
# ['apple', 'orange', 'cherry', 'apple']

# %%
listfruits=["apple","orange","cherry"]
listfruits.append("banana")
print(listfruits)
# Out:
# ['apple', 'orange', 'cherry', 'banana']

# %%
listfruits=["apple","orange","cherry"]
print(listfruits[0])
listfruits.append("banana")
print(listfruits)
# Out:
# apple
# ['apple', 'orange', 'cherry', 'banana']

# %%
listfruits=["apple","orange","cherry"]
print(listfruits[0])
print(listfruits[-2])
listfruits.append("banana")
print(listfruits)
# Out:
# apple
# orange
# ['apple', 'orange', 'cherry', 'banana']

# %%
listfruits=["apple","orange","cherry"]
print(listfruits[0])
print(listfruits[-2])
listfruits.append("banana")
print(listfruits)
print(listfruits[0])
print(listfruits[-2])
listfruits.append("banana")
print(listfruits)
# Out:
# apple
# orange
# ['apple', 'orange', 'cherry', 'banana']
# apple
# cherry
# ['apple', 'orange', 'cherry', 'banana', 'banana']

# %%
listfruits=["apple","orange","cherry"]
listfruits.insert(1,"banana")
print(listfruits)
# Out:
# ['apple', 'banana', 'orange', 'cherry']

# %%
listfruits=["apple","orange","cherry"]
listfruits[1]="banana"
print(listfruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
list1=["apple","orange","cherry"]
list2=["mango","pineapple","banana"]
list1.extend(list2)
print(list1)
# Out:
# ['apple', 'orange', 'cherry', 'mango', 'pineapple', 'banana']

# %%
list1=["apple","banana","cherry","kiwi","mango","pineapple"]
print(list1[2:5])
print(list1[2:])
print(list1[:4])
# Out:
# ['cherry', 'kiwi', 'mango']
# ['cherry', 'kiwi', 'mango', 'pineapple']
# ['apple', 'banana', 'cherry', 'kiwi']

# %%
list=["riya","rivya","darsh","falak","divisha"]
print(list)
print(list[0])
print(list[4])
list.append("adi")
print(list)
list.remove("adi")
print(list)
# Out:
# ['riya', 'rivya', 'darsh', 'falak', 'divisha']
# riya
# divisha
# ['riya', 'rivya', 'darsh', 'falak', 'divisha', 'adi']
# ['riya', 'rivya', 'darsh', 'falak', 'divisha']

# %%
marks=["34","23","98","77","20"]
marks_as_int = [int(mark) for mark in marks]
print(max(marks_as_int))
print(min(marks_as_int))
print(sum(marks_as_int))
print(len(marks_as_int))
print(sorted(marks_as_int))
# Out:
# 98
# 20
# 252
# 5
# [20, 23, 34, 77, 98]
